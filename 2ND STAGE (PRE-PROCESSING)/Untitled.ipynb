# %% [markdown]
# ## GIRIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\data2\\OneDrive\\Masaüstü\\codeware\\app_store\\veri.csv")

# %%
data.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %% [markdown]
# ## Genel Bakis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7197 non-null   int64
#  1   id                7197 non-null   int64
#  2   track_name        7197 non-null   object
#  3   size_bytes        7197 non-null   int64
#  4   currency          7197 non-null   object
#  5   price             7197 non-null   float64
#  6   rating_count_tot  7197 non-null   int64
#  7   rating_count_ver  7197 non-null   int64
#  8   user_rating       7197 non-null   float64
#  9   user_rating_ver   7197 non-null   float64
#  10  ver               7197 non-null   object
#  11  cont_rating       7197 non-null   object
#  12  prime_genre       7197 non-null   object
#  13  sup_devices.num   7197 non-null   int64
#  14  ipadSc_urls.num   7197 non-null   int64
#  15  lang.num          7197 non-null   int64
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0            id    size_bytes        price  \
# count   7197.000000  7.197000e+03  7.197000e+03  7197.000000
# mean    4759.069612  8.631310e+08  1.991345e+08     1.726218
# std     3093.625213  2.712368e+08  3.592069e+08     5.833006
# min        1.000000  2.816565e+08  5.898240e+05     0.000000
# 25%     2090.000000  6.000937e+08  4.692275e+07     0.000000
# 50%     4380.000000  9.781482e+08  9.715302e+07     0.000000
# 75%     7223.000000  1.082310e+09  1.819249e+08     1.990000
# max    11097.000000  1.188376e+09  4.025970e+09   299.990000
#
#        rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# count      7.197000e+03       7197.000000  7197.000000      7197.000000
# mean       1.289291e+04        460.373906     3.526956         3.253578
# std        7.573941e+04       3920.455183     1.517948         1.809363
# min        0.000000e+00          0.000000     0.000000         0.000000
# ...

# %% [markdown]
# ## DataFrame duzenleme

# %%
data.drop(columns=["Unnamed: 0","currency"], inplace=True)

# %%
data.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
# ...

# %%
data["notFree"]=data["price"]>0

# %%
data["size_bytes"] =data["size_bytes"].apply(lambda x:x/1024)

# %%
data.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium     98426.0
# 1  281796108                          Evernote - stay organized    154862.0
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts     98168.0
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...    125500.0
# 4  282935706                                              Bible     90600.0
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
# ...

# %%
data["cont_rating"]=data["cont_rating"].apply(lambda x: x[:-1])

# %%
data["cont_rating"]=data["cont_rating"].astype(float)

# %%
data["cont_rating"]=data["cont_rating"]/5

# %% [markdown]
# ## Gorsellestirme

# %%
data.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium     98426.0
# 1  281796108                          Evernote - stay organized    154862.0
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts     98168.0
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...    125500.0
# 4  282935706                                              Bible     90600.0
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
# ...

# %%
plt.figure(figsize=(6,8))
plt.bar(data['prime_genre'], data['price'], color='skyblue')
plt.xticks([])
plt.show()

# %% [markdown]
# # pairplot , corr

# %% [markdown]
# #### KOD COK FAZLA VERIDEN DOLAYI CALISMADI

# %%
heat_map=data.iloc[:,2:4]

# %%
#sns.heatmap(heat_map, cmap='coolwarm', annot=True, fmt=".1f", linewidths=.5)

#plt.show()

# %%
a=data["prime_genre"].value_counts()
print(a)
# Out:
# prime_genre
# Games                3862
# Entertainment         535
# Education             453
# Photo & Video         349
# Utilities             248
# Health & Fitness      180
# Productivity          178
# Social Networking     167
# Lifestyle             144
# Music                 138
# Shopping              122
# Sports                114
# Book                  112
# Finance               104
# Travel                 81
# News                   75
# Weather                72
# Reference              64
# Food & Drink           63
# Business               57
# Navigation             46
# Medical                23
# Catalogs               10
# Name: count, dtype: int64

# %%
heat_map2=data[["price","size_bytes"]]

# %%
sns.heatmap(heat_map,cmap='coolwarm', annot=True, fmt=".1f", linewidths=.5 )
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8, 6))
plt.pie(a, labels=a.index, autopct='%1.1f%%', startangle=140)
plt.show()

# %% [markdown]
# ## Makine Ogrenmesi Modelleri

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
